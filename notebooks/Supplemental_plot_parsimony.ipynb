# %%
# add the R package ape
library(ape)

# %%
options(repr.plot.width=6, repr.plot.height=6)
par(bg="white")
tree_string_balanced <- "((((A:1,B:1):1,(C:1,D:1):1):1,((E:1,F:1):1,(G:1,H:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_balanced)
# set the first branch length to 0.5
tree_1$edge.length[1] <- 0.2
plot(tree_1, cex = 0.8, edge.width = 2, main = "Balanced tree with 8 tips", type="c")

edgelabels()
# Out:
# Plot with title "Balanced tree with 8 tips"

# %%
# set figure dimensions for Jupyter
options(repr.plot.width = 8, repr.plot.height = 4)

# Now put all three trees in one plot
par(bg="white")
layout(matrix(c(1, 2, 3, 4), nrow = 1, ncol = 4))

tree_string_1 <- "((((A:1,B:1):1,(A:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(5, 8, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)

## Second tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)

## Second tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,A:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 13)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)

## Third tree
tree_string_1 <- "((((A:1,A:1):1,(A:1,A:1):1):1,((B:1,B:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(2)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)

dev.copy2pdf(file = "four_trees_cr.pdf", width = 8, height = 4)
dev.off()
# Out:
# pdf
#   2
# null device
#           1
# Plot with title "Parsimony score is 1"

# %%
# set figure dimensions for Jupyter
options(repr.plot.width = 8, repr.plot.height = 4)

letters <- c("AAAAA", "B", "C", "D")

# Now put all three trees in one plot
par(bg="white")
layout(matrix(c(1, 2, 3, 4), nrow = 1, ncol = 4))

tree_string_1 <- "((((A:1,B:1):1,(A:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(5, 8, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)
# put letters[1] on the top left corner of the plot. Use the plot coordinates to place the text


## Second tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)

## Second tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,A:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 13)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)

## Third tree
tree_string_1 <- "((((A:1,A:1):1,(A:1,A:1):1):1,((B:1,B:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(2)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)

dev.copy2pdf(file = "four_trees_pr.pdf", width = 8, height = 4)
dev.off()
# Out:
# pdf
#   2
# null device
#           1
# Plot with title "Parsimony score is 1"

# %%
# set figure dimensions for Jupyter
options(repr.plot.width = 8, repr.plot.height = 4)

letters <- c("A", "B", "C", "D")

# Now put all three trees in one plot
par(bg="white")
layout(matrix(c(1, 2, 3, 4), nrow = 1, ncol = 4))

## First
tree_string_1 <- "((((A:1,A:1):1,(A:1,A:1):1):1,((B:1,B:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(2)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)
# place an "A" on the top left corner of the plot.
usr <- par("usr")
text(usr[1], usr[4], letters[1], adj = c(0,1), font = 1, cex = 2)


## Second tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,A:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 13)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)
# label B
text(usr[1], usr[4], letters[2], adj = c(0,1), font = 1, cex = 2)


## Third tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)
# label C
text(usr[1], usr[4], letters[3], adj = c(0,1), font = 1, cex = 2)

# fourth
tree_string_1 <- "((((A:1,B:1):1,(A:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(5, 8, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "p", edge.color = co_vector)
# label D
text(usr[1], usr[4], letters[4], adj = c(0,1), font = 1, cex = 2)


dev.copy2pdf(file = "four_trees_p.pdf", width = 8, height = 4)
dev.copy2pdf(file = "fig_S5.pdf", width = 8, height = 4)
dev.off()
# Out:
# pdf
#   2
# pdf
#   2
# null device
#           1
# Plot with title "Parsimony score is 4"

# %%
# set figure dimensions for Jupyter
options(repr.plot.width = 8, repr.plot.height = 4)

letters <- c("AAAAA", "B", "C", "D")

# Now put all three trees in one plot
par(bg="white")
layout(matrix(c(1, 2, 3, 4), nrow = 1, ncol = 4))

## First
tree_string_1 <- "((((A:1,A:1):1,(A:1,A:1):1):1,((B:1,B:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(2)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)


## Second tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,A:1):1,(B:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 13)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)

## Third tree
tree_string_1 <- "((((A:1,A:1):1,(B:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(6, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)


# fourth
tree_string_1 <- "((((A:1,B:1):1,(A:1,B:1):1):1,((A:1,B:1):1,(A:1,B:1):1):1):1);"
tree_1 <- ape::read.tree(text = tree_string_1)
tree_1$edge.length[1] <- 0.2
co_vector <- rep("black", length(tree_1$edge))
mask <- c(5, 8, 12, 15)
co_vector[mask] <- "red"
plot(tree_1, cex = 2, edge.width = 2, main = paste0("Parsimony score is ", length(mask)), type = "c", edge.color = co_vector)
# put letters[1] on the top left corner of the plot. Use the plot coordinates to place the text


dev.copy2pdf(file = "four_trees_c.pdf", width = 8, height = 4)
dev.off()
# Out:
# pdf
#   2
# null device
#           1
# Plot with title "Parsimony score is 4"
